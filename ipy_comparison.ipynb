# %% [markdown]
# ### 6.3 MNIST

# %%
# !python exp3_mnist.py --model CSKN8
# !python exp3_mnist.py --model CRFFNet8

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_MNIST_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_MNIST_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_MNIST_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_MNIST_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_MNIST_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_MNIST_shufflenet.pt')
plt.plot(range(1, 31), checkpoint_cskn8['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_crffnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_resnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_densenet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_vgg['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_shufflenet['test_acc_arr'].mean(0)[:30])
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

print(checkpoint_shufflenet['test_acc_arr'].mean(1))
# Out:
# [98.21533333 98.533      98.68266667 98.76533333 98.79766667 98.825
#  98.88433333 98.86366667 98.856      98.885     ]

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_FashionMNIST_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_FashionMNIST_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_FashionMNIST_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_FashionMNIST_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_FashionMNIST_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_FashionMNIST_shufflenet.pt')
plt.plot(range(1, 31), checkpoint_cskn8['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_crffnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_resnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_densenet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_vgg['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_shufflenet['test_acc_arr'].mean(0)[:30])
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()


print(checkpoint_cskn8['test_acc_arr'].mean(0))

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_CIFAR10_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_CIFAR10_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_CIFAR10_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_CIFAR10_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_CIFAR10_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_CIFAR10_shufflenet.pt')
plt.plot(range(1, 31), checkpoint_cskn8['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_crffnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_resnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_densenet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_vgg['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_shufflenet['test_acc_arr'].mean(0)[:30])
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_CIFAR100_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_CIFAR100_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_CIFAR100_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_CIFAR100_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_CIFAR100_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_CIFAR100_shufflenet.pt')
plt.plot(range(1, 31), checkpoint_cskn8['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_crffnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_resnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_densenet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_vgg['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_shufflenet['test_acc_arr'].mean(0)[:30])
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_TinyImagenet_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_TinyImagenet_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_TinyImagenet_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_TinyImagenet_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_TinyImagenet_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_TinyImagenet_shufflenet.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].mean(0))
plt.plot(checkpoint_crffnet['test_acc_arr'].mean(0))
plt.plot(checkpoint_resnet['test_acc_arr'].mean(0))
plt.plot(checkpoint_densenet['test_acc_arr'].mean(0))
plt.plot(checkpoint_vgg['test_acc_arr'].mean(0))
plt.plot(checkpoint_shufflenet['test_acc_arr'].mean(0))
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
from models import CSKN8, CRFFNet8, PretrainModel
import matplotlib.pyplot as plt
import torch
from thop import profile

model_arr = ['CSKN8', 'CRFFNet8', 'resnet', 'vgg', 'densenet', 'shufflenet']
flops_arr = []
params_arr = []

lr0 = 1e-4
lr1 = 1e-5
sigma0 = 1e-6
sigma1 = 1e-6
growth_factor = 4
input = torch.randn(1, 1, 32, 32)
flops, params = profile(CSKN8(2048, 10, 1, sigma0, sigma1, growth_factor), inputs = (input, ))
flops_arr.append(flops)
params_arr.append(params)

flops, params = profile(CRFFNet8(2048, 10, 1, sigma0), inputs = (input, ))
flops_arr.append(flops)
params_arr.append(params)

network = 'resnet'
flops, params = profile(PretrainModel(network, 1, 10), inputs = (input, ))
flops_arr.append(flops)
params_arr.append(params)

network = 'vgg'
flops, params = profile(PretrainModel(network, 1, 10), inputs = (input, ))
flops_arr.append(flops)
params_arr.append(params)

network = 'densenet'
flops, params = profile(PretrainModel(network, 1, 10), inputs = (input, ))
flops_arr.append(flops)
params_arr.append(params)

network = 'shufflenet'
flops, params = profile(PretrainModel(network, 1, 10), inputs = (input, ))
flops_arr.append(flops)
params_arr.append(params)

for i in range(len(params_arr)):
    print('{} --- FLOPs: {} M, # Params: {} M'.format(model_arr[i], flops_arr[i]/1000**2, format(params_arr[i]/1000**2)))
# Out:
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register count_avgpool() for <class 'torch.nn.modules.pooling.AvgPool2d'>.
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.ModuleList'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_bn() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [WARN] Cannot find rule for <class 'models.CSKN8'>. Treat it as zero Macs and zero Params.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register count_avgpool() for <class 'torch.nn.modules.pooling.AvgPool2d'>.
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.ModuleList'>. Treat it as zero Macs and zero Params.
# ...

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp_comparison_MNIST_CSKN8_E30_R10.pt')
checkpoint_crffnet = torch.load('./results/exp_comparison_MNIST_CRFFNet8_E30_R10.pt')
checkpoint_resnet = torch.load('./results/exp3_MNIST_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_MNIST_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_MNIST_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_MNIST_shufflenet.pt')
plt.plot(range(1, 31), checkpoint_cskn8['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_crffnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_resnet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_densenet['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_vgg['test_acc_arr'].mean(0)[:30])
plt.plot(range(1, 31), checkpoint_shufflenet['test_acc_arr'].mean(0)[:30])
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

print(checkpoint_shufflenet['test_acc_arr'].mean(1))
# Out:
# [98.21533333 98.533      98.68266667 98.76533333 98.79766667 98.825
#  98.88433333 98.86366667 98.856      98.885     ]

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_MNIST_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_MNIST_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_MNIST_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_MNIST_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_MNIST_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_MNIST_shufflenet.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_crffnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_resnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_densenet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_vgg['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_shufflenet['test_acc_arr'].reshape(-1))
# plt.ylim(98, 100)
plt.xlim(0, 299)
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_FashionMNIST_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_FashionMNIST_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_FashionMNIST_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_FashionMNIST_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_FashionMNIST_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_FashionMNIST_shufflenet.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_crffnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_resnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_densenet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_vgg['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_shufflenet['test_acc_arr'].reshape(-1))
# plt.ylim(98, 99.6)
plt.xlim(0, 299)
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_CIFAR10_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_CIFAR10_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_CIFAR10_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_CIFAR10_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_CIFAR10_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_CIFAR10_shufflenet.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_crffnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_resnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_densenet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_vgg['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_shufflenet['test_acc_arr'].reshape(-1))
# plt.ylim(98, 99.6)
plt.xlim(0, 299)
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_CIFAR100_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_CIFAR100_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_CIFAR100_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_CIFAR100_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_CIFAR100_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_CIFAR100_shufflenet.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_crffnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_resnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_densenet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_vgg['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_shufflenet['test_acc_arr'].reshape(-1))
# plt.ylim(98, 99.6)
plt.xlim(0, 299)
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_TinyImagenet_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_TinyImagenet_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_TinyImagenet_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_TinyImagenet_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_TinyImagenet_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_TinyImagenet_shufflenet.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_crffnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_resnet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_densenet['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_vgg['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_shufflenet['test_acc_arr'].reshape(-1))
# plt.ylim(98, 99.6)
plt.xlim(0, 299)
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp_comparison_MNIST_CSKN8_E30_R10.pt')
checkpoint_crffnet = torch.load('./results/exp_comparison_MNIST_CRFFNet8_E30_R10.pt')
# checkpoint_resnet = torch.load('./results/exp_comparison_MNIST_resnet_E30_R10.pt')
# checkpoint_densenet = torch.load('./results/exp_comparison_MNIST_densenet_E30_R10.pt')
# checkpoint_vgg = torch.load('./results/exp_comparison_MNIST_vgg_E30_R10.pt')
# checkpoint_shufflenet = torch.load('./results/exp_comparison_MNIST_shufflenet_E30_R10.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].mean(0))
plt.plot(checkpoint_crffnet['test_acc_arr'].mean(0))
# plt.plot(checkpoint_resnet['test_acc_arr'].reshape(-1))
# plt.plot(checkpoint_densenet['test_acc_arr'].reshape(-1))
# plt.plot(checkpoint_vgg['test_acc_arr'].reshape(-1))
# plt.plot(checkpoint_shufflenet['test_acc_arr'].reshape(-1))
plt.ylim(98, 99.6)
# plt.xlim(0, 299)
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()

# %%
import torch
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt

checkpoint_cskn8 = torch.load('./results/exp3_MNIST_CSKN8.pt')
checkpoint_crffnet = torch.load('./results/exp3_MNIST_CRFFNet8.pt')
checkpoint_resnet = torch.load('./results/exp3_MNIST_resnet.pt')
checkpoint_densenet = torch.load('./results/exp3_MNIST_densenet.pt')
checkpoint_vgg = torch.load('./results/exp3_MNIST_vgg.pt')
checkpoint_shufflenet = torch.load('./results/exp3_MNIST_shufflenet.pt')
plt.plot(checkpoint_cskn8['test_acc_arr'].reshape(-1))
plt.plot(checkpoint_crffnet['test_acc_arr'].reshape(-1))
# plt.plot(checkpoint_resnet['test_acc_arr'].reshape(-1))
# plt.plot(checkpoint_densenet['test_acc_arr'].reshape(-1))
# plt.plot(checkpoint_vgg['test_acc_arr'].reshape(-1))
# plt.plot(checkpoint_shufflenet['test_acc_arr'].reshape(-1))
plt.ylim(98, 99.6)
plt.xlim(0, 29)
plt.legend(['CSKN8', 'CRFFNet8', 'Resnet', 'Densenet', 'VGG', 'Shufflenet'])
plt.show()
