# %% [markdown]
# ### Distributions of exp_ablation 0

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
plt.style.use('seaborn-white')

checkpoint_SKN = torch.load('./results/exp_ablation0_SKN.pt')

f = plt.figure()
data00 = checkpoint_SKN['weights0'][0][:, 0]
weights00 = np.ones_like(data00)/float(len(data00))
plt.hist(data00, alpha=0.3, bins=50, weights=weights00, color='r')
# plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Initial weight for $p(\omega$)')
plt.show()
f.savefig('./results/exp_ablation0_weight00.pdf', bbox_inches='tight')

f = plt.figure()
data01 = checkpoint_SKN['weights0'][1][:, 0]
weights01 = np.ones_like(data01)/float(len(data01))
plt.hist(data01, alpha=0.3, bins=50, weights=weights01, color='b')
# plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
f.savefig('./results/exp_ablation0_weight01.pdf', bbox_inches='tight')


f = plt.figure()
data10 = checkpoint_SKN['weights1'][0][:, 0]
weights10 = np.ones_like(data10)/float(len(data10))
plt.hist(data10, alpha=0.3, bins=50, weights=weights10, color='r')
# plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Initial weight for $p(\omega\'$)')
plt.show()
f.savefig('./results/exp_ablation0_weight10.pdf', bbox_inches='tight')

f = plt.figure()
data11 = checkpoint_SKN['weights1'][1][:, 0]
weights11 = np.ones_like(data11)/float(len(data11))
plt.hist(data11, alpha=0.3, bins=50, weights=weights11, color='b')
# plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Optimized weight for $p(\omega\'$)')
plt.show()
f.savefig('./results/exp_ablation0_weight11.pdf', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
plt.style.use('seaborn-white')

checkpoint_SKN = torch.load('./results/exp_ablation0_SKN.pt')
data_tmp = np.random.normal(0, 0.08, 10000)

f = plt.figure()
data00 = checkpoint_SKN['weights0'][0][:, 300]
data01 = checkpoint_SKN['weights0'][1][:, 300]
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
f.savefig('./results/exp_ablation0_weight0.pdf', bbox_inches='tight')

f = plt.figure()
data10 = checkpoint_SKN['weights1'][0][:, 300]
data11 = checkpoint_SKN['weights1'][1][:, 300]
sns.distplot(data10, kde=True, color="r", bins=100)
sns.distplot(data11, kde=True, norm_hist=True, color="b", bins=100)
sns.distplot(data_tmp, kde=True, norm_hist=True, color="b", bins=100)
plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Optimized weight for $p(\omega$)')
plt.ylim(0, 20)
plt.show()
f.savefig('./results/exp_ablation0_weight1.pdf', bbox_inches='tight')
# Out:
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Distributions of exp_ablation 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
plt.style.use('seaborn-white')
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

data_tmp = np.random.normal(0, 0.03, 10000)

f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 0.3, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')
# Out:
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
plt.style.use('seaborn-white')


data_tmp = np.random.normal(0, 0.02, 10000)

f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_3layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_3layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 0.16, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_3layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_3layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 2.56, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_3layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.2.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_3layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.2.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')



f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list1.0.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list1.0.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 0.3, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list1.1.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list1.1.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 0.3, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list1.2.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_2layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list1.2.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')
# Out:
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
plt.style.use('seaborn-white')


data_tmp = np.random.normal(0, 0.015, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 0.16, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 2.56, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.2.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.2.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')


data_tmp = np.random.normal(0, 40.96, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.3.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_4layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.3.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')
# Out:
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
plt.style.use('seaborn-white')


data_tmp = np.random.normal(0, 0.012, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.0.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 0.08, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.1.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 0.64, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.2.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.2.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')


data_tmp = np.random.normal(0, 5, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.3.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.3.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')

data_tmp = np.random.normal(0, 6, 10000)
f = plt.figure()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_initial.pt')
data00 = checkpoint_SKN['intial_weight']['op_list0.3.weight'][:, 300].cpu().numpy()
checkpoint_SKN = torch.load('./results/exp_ablation1_5layer_final.pt')
data01 = checkpoint_SKN['final_weight']['op_list0.3.weight'][:, 300].cpu().numpy()
sns.distplot(data00)
sns.distplot(data01)
sns.distplot(data_tmp)
plt.legend(['Initial spectral density', 'Optimized spectral density', 'Fit density'])
plt.title('Optimized weight for $p(\omega$)')
plt.show()
# f.savefig('./results/exp_ablation1_3laweight0.pdf', bbox_inches='tight')
# Out:
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/superlj666/anaconda3/envs/torch/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
